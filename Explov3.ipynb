# %%
import duckdb
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from datetime import datetime

# Connexion
con = duckdb.connect("football.duckdb")

# Sécurité mémoire
con.execute("PRAGMA threads=4;")
con.execute("PRAGMA memory_limit='4GB';")

print("DuckDB ready")
# Out:
# DuckDB ready

# %%
df_speed_max = con.execute("""
SELECT
    player_name,
    MAX(speed_kmh) AS max_speed_kmh
FROM tracking_clean_speed
GROUP BY player_name
ORDER BY max_speed_kmh DESC
""").df()

print(df_speed_max)
print(df_speed_max.shape)
# Out:
#     player_name  max_speed_kmh
# 0        SIDLER      166.08996
# 1     CARBONELL      149.78448
# 2         IBRAH      147.07368
# 3          VOCA      122.18940
# 4      CIRKOVIC      108.66240
# 5         MALES       85.11228
# 6      KNEZEVIC       79.58520
# 7         ELEKE       73.07172
# 8        FRYDEK       69.73056
# 9     SCHWEGLER       69.29136
# 10       SORGIC       69.05196
# 11    MARGIOTTA       68.07708
# 12       SCHAUB       66.98268
# 13        RYDER       66.55104
# 14        ALVES       66.24900
# 15      GRETHER       63.87624
# 16      SCHURPF       63.48456
# 17    KAKABADZE       52.51320
# 18        BÜRKI       51.87060
# 19     DEMHASAJ       43.18596
# 20       NDENGE       39.55464
# 21       SCHULZ       39.31308
# 22        BURCH       36.87516
# 23    SCHNEUWLY       36.72900
# 24          TIA       35.60760
# 25      ALOUNGA       33.61104
# 26        TAZAR       33.51600
# 27       BINOUS       33.00552
# 28    BALATUBAN       32.96412
# 29            F       32.14728
# 30         LINO       31.39308
# 31         LANG       30.87540
# 32        ALABI       30.74904
# 33  MISTVAFOVIC       30.41856
# 34      MARLEKU       30.38868
# 35       ARNOLD       29.89224
# 36        EMINI       29.78208
# 37       STEFAN       29.52468
# 38    FOLLONIER       29.45772
# 39        OWUSU       29.36772
# 40      JASHARI       28.88676
# 41            M       26.48376
# (42, 2)
